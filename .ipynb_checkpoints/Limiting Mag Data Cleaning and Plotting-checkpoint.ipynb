# %%
import pandas as pd
import numpy as np
import requests
import json
import os
import pprint
# from statesjson import us_states_json
# from states import us_states
from citipy import citipy

# %%
DSD = pd.read_csv("Dark_Sky_Data.csv")

# %%
DSD
# Out:
#                                     Country  Limiting Magnitude        Date  \
# 0                   United States - Alabama                   7  2009-03-22
# 1                   United States - Alabama                   7  2009-03-19
# 2                   United States - Alabama                   7  2009-03-22
# 3                   United States - Alabama                   7  2009-03-23
# 4                   United States - Alabama                   6  2015-08-13
# ...                                     ...                 ...         ...
# 82492  United States - District of Columbia               -9999  2017-07-21
# 82493  United States - District of Columbia               -9999  2010-03-12
# 82494  United States - District of Columbia               -9999  2010-03-11
# 82495  United States - District of Columbia               -9999  2007-03-22
# 82496  United States - District of Columbia               -9999  2017-07-20
#
#                Coordinates  Longitude  Latitude
# 0       [33.0428, -87.394]   -87.3940   33.0428
# 1       [33.4033, -86.385]   -86.3850   33.4033
# 2      [32.6994, -86.7865]   -86.7865   32.6994
# 3      [33.0326, -87.2895]   -87.2895   33.0326
# 4      [34.7287, -86.7437]   -86.7437   34.7287
# ...                    ...        ...       ...
# 82492  [38.9652, -77.0234]   -77.0234   38.9652
# 82493  [38.9014, -76.9829]   -76.9829   38.9014
# 82494  [38.9012, -77.0007]   -77.0007   38.9012
# 82495      [38.95, -77.08]   -77.0800   38.9500
# 82496  [38.9652, -77.0235]   -77.0235   38.9652
#
# [82497 rows x 6 columns]

# %%
PC = pd.read_csv("Park Coordinates.csv")
pcrounded = PC.round({"Latitude": 4, "Longitude": 3})
#round to make sure data matches between two DFs

# %%
pcrounded
# Out:
#     Latitude  Longitude                                         Park
# 0    44.3386    -68.273                         Acadia National Park
# 1   -14.2583   -170.683              National Park of American Samoa
# 2    38.7331   -109.593                         Arches National Park
# 3    43.8554   -102.340                       Badlands National Park
# 4    29.1275   -103.243                       Big Bend National Park
# ..       ...        ...                                          ...
# 57   43.6046   -103.421                      Wind Cave National Park
# 58   61.7104   -142.986  Wrangell-St. Elias National Park & Preserve
# 59   44.4280   -110.588                    Yellowstone National Park
# 60   37.8651   -119.538                       Yosemite National Park
# 61   37.2982   -113.026                           Zion National Park
#
# [62 rows x 3 columns]

# %%
def cartesian_product_basic(left, right):
    return (
       DSD.assign(key=1).merge(pcrounded.assign(key=1), on='key').drop('key', 1))
dsd_merged_df = cartesian_product_basic(DSD, pcrounded)
#Credit: Umair Khakoo

# %%
dsd_merged_df
# Out:
#                                       Country  Limiting Magnitude        Date  \
# 0                     United States - Alabama                   7  2009-03-22
# 1                     United States - Alabama                   7  2009-03-22
# 2                     United States - Alabama                   7  2009-03-22
# 3                     United States - Alabama                   7  2009-03-22
# 4                     United States - Alabama                   7  2009-03-22
# ...                                       ...                 ...         ...
# 5114809  United States - District of Columbia               -9999  2017-07-20
# 5114810  United States - District of Columbia               -9999  2017-07-20
# 5114811  United States - District of Columbia               -9999  2017-07-20
# 5114812  United States - District of Columbia               -9999  2017-07-20
# 5114813  United States - District of Columbia               -9999  2017-07-20
#
#                  Coordinates  Longitude_x  Latitude_x  Latitude_y  \
# 0         [33.0428, -87.394]     -87.3940     33.0428     44.3386
# 1         [33.0428, -87.394]     -87.3940     33.0428    -14.2583
# 2         [33.0428, -87.394]     -87.3940     33.0428     38.7331
# 3         [33.0428, -87.394]     -87.3940     33.0428     43.8554
# 4         [33.0428, -87.394]     -87.3940     33.0428     29.1275
# ...                      ...          ...         ...         ...
# 5114809  [38.9652, -77.0235]     -77.0235     38.9652     43.6046
# 5114810  [38.9652, -77.0235]     -77.0235     38.9652     61.7104
# 5114811  [38.9652, -77.0235]     -77.0235     38.9652     44.4280
# 5114812  [38.9652, -77.0235]     -77.0235     38.9652     37.8651
# 5114813  [38.9652, -77.0235]     -77.0235     38.9652     37.2982
#
#          Longitude_y                                         Park
# 0            -68.273                         Acadia National Park
# 1           -170.683              National Park of American Samoa
# 2           -109.593                         Arches National Park
# 3           -102.340                       Badlands National Park
# 4           -103.243                       Big Bend National Park
# ...              ...                                          ...
# 5114809     -103.421                      Wind Cave National Park
# 5114810     -142.986  Wrangell-St. Elias National Park & Preserve
# 5114811     -110.588                    Yellowstone National Park
# 5114812     -119.538                       Yosemite National Park
# 5114813     -113.026                           Zion National Park
#
# [5114814 rows x 9 columns]

# %%
dsd_df_unclean = dsd_merged_df[
    ((abs(dsd_merged_df["Latitude_x"] - dsd_merged_df["Latitude_y"])) <= 0.44) &\
    ((abs(dsd_merged_df["Longitude_x"] - dsd_merged_df["Longitude_y"])) <= 0.44)
]

# %%
dsd_date_unclean = pd.to_datetime(dsd_merged_df["Date"])
dsd_date_df = pd.DataFrame(dsd_date_unclean)

# %%
dsd_date_drop = dsd_df_unclean.drop(columns= "Date")
dsd_df = dsd_date_drop.merge(dsd_date_df, left_index = True, right_index = True)

# %%
dsd_df
# Out:
#                          Country  Limiting Magnitude          Coordinates  \
# 25284     United States - Alaska                   3  [32.2251, -110.996]
# 28977    United States - Arizona                   7    [36.0717, -112.2]
# 29039    United States - Arizona                   7  [36.0723, -112.166]
# 29101    United States - Arizona                   7  [36.0721, -112.148]
# 29163    United States - Arizona                   7  [36.0664, -112.146]
# ...                          ...                 ...                  ...
# 5107956  United States - Wyoming                   4  [43.5873, -110.828]
# 5108080  United States - Wyoming                   4  [43.8397, -110.511]
# 5109010  United States - Wyoming                   2  [43.9819, -110.663]
# 5109444  United States - Wyoming                -999  [43.4673, -110.787]
# 5109568  United States - Wyoming               -9999  [43.5874, -110.711]
#
#          Longitude_x  Latitude_x  Latitude_y  Longitude_y  \
# 25284       -110.996     32.2251     32.2967     -111.167
# 28977       -112.200     36.0717     36.1070     -112.113
# 29039       -112.166     36.0723     36.1070     -112.113
# 29101       -112.148     36.0721     36.1070     -112.113
# 29163       -112.146     36.0664     36.1070     -112.113
# ...              ...         ...         ...          ...
# 5107956     -110.828     43.5873     43.7410     -110.802
# 5108080     -110.511     43.8397     43.7410     -110.802
# 5109010     -110.663     43.9819     43.7410     -110.802
# 5109444     -110.787     43.4673     43.7410     -110.802
# 5109568     -110.711     43.5874     43.7410     -110.802
#
#                                Park       Date
# 25284         Saguaro National Park 2014-03-30
# 28977    Grand Canyon National Park 2015-06-13
# 29039    Grand Canyon National Park 2015-06-15
# 29101    Grand Canyon National Park 2015-06-15
# 29163    Grand Canyon National Park 2015-06-15
# ...                             ...        ...
# 5107956                 Grand Teton 2014-07-25
# 5108080                 Grand Teton 2017-08-15
# 5109010                 Grand Teton 2015-06-19
# 5109444                 Grand Teton 2015-02-01
# 5109568                 Grand Teton 2017-10-07
#
# [10690 rows x 9 columns]

# %%
dsd_df_no999 = dsd_df[dsd_df["Limiting Magnitude"] != -999]
dsd_df_clean = dsd_df_no999[dsd_df_no999["Limiting Magnitude"] != -9999]

# %%
dsd_pivot = pd.pivot_table(dsd_df_clean, values = "Limiting Magnitude", index = ["Date"], columns = ["Park"])\
    .reset_index(drop=True)\
    .assign(Date=pd.to_datetime(dsd_pivot["Date"]) + pd.offsets.MonthBegin(0))
# Out:
# Park  Acadia National Park  Arches National Park  Badlands National Park  \
# 0                      NaN                   NaN                     NaN
# 1                      NaN                   NaN                     NaN
# 2                      NaN                   NaN                     NaN
# 3                      NaN                   NaN                     NaN
# 4                      NaN                   NaN                     NaN
# ..                     ...                   ...                     ...
# 976                    NaN                   NaN                     NaN
# 977                    NaN                   NaN                     NaN
# 978                    NaN                   NaN                     NaN
# 979                    NaN                   NaN                     NaN
# 980                    NaN                   NaN                     NaN
#
# Park  Big Bend National Park  Biscayne National Park  \
# 0                        NaN                     NaN
# 1                        NaN                     NaN
# 2                        NaN                     NaN
# 3                        NaN                     NaN
# 4                        NaN                     NaN
# ..                       ...                     ...
# 976                      NaN                     NaN
# 977                      NaN                     NaN
# 978                      NaN                     NaN
# 979                      NaN                     1.0
# 980                      NaN                     NaN
#
# Park  Black Canyon of the Gunnison National Park  Bryce Canyon National Park  \
# 0                                            NaN                         NaN
# 1                                            NaN                         NaN
# 2                                            NaN                         NaN
# 3                                            NaN                         NaN
# 4                                            NaN                         NaN
# ..                                           ...                         ...
# 976                                          NaN                         NaN
# 977                                          NaN                         NaN
# 978                                          NaN                         NaN
# 979                                          NaN                         NaN
# 980                                          NaN                         NaN
#
# Park  Canyonlands National Park  Capitol Reef National Park  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
# ..                          ...                         ...
# 976                         NaN                         NaN
# 977                         NaN                         NaN
# 978                         NaN                         NaN
# 979                         NaN                         NaN
# 980                         NaN                         NaN
#
# Park  Carlsbad Caverns National Park  ...  Rocky Mountain National Park  \
# 0                                NaN  ...                      4.000000
# 1                                NaN  ...                      3.750000
# 2                                NaN  ...                           NaN
# 3                                NaN  ...                           NaN
# 4                                NaN  ...                           NaN
# ..                               ...  ...                           ...
# 976                              NaN  ...                      2.750000
# 977                              NaN  ...                      2.333333
# 978                              NaN  ...                      3.000000
# 979                              NaN  ...                      2.800000
# 980                              NaN  ...                           NaN
#
# Park  Saguaro National Park  Sequoia & Kings Canyon National Parks  \
# 0                  4.941176                                    NaN
# 1                  4.692308                                    NaN
# 2                  4.555556                                    NaN
# 3                  4.400000                                    NaN
# 4                  4.300000                                    NaN
# ..                      ...                                    ...
# 976                     NaN                                    NaN
# 977                3.000000                                    NaN
# 978                3.000000                                    NaN
# 979                     NaN                                    NaN
# 980                2.000000                                    NaN
#
# Park  Shenandoah National Park  Theodore Roosevelt National Park  \
# 0                          NaN                               NaN
# 1                          NaN                               NaN
# 2                          4.0                               NaN
# 3                          NaN                               NaN
# 4                          NaN                               NaN
# ..                         ...                               ...
# 976                        NaN                               NaN
# 977                        NaN                               NaN
# 978                        NaN                               NaN
# 979                        NaN                               NaN
# 980                        NaN                               NaN
#
# Park  Voyageurs National Park  White Sands National Park  \
# 0                         NaN                        NaN
# 1                         NaN                        NaN
# 2                         NaN                        NaN
# 3                         NaN                        NaN
# 4                         NaN                        NaN
# ..                        ...                        ...
# 976                       NaN                        NaN
# 977                       NaN                        NaN
# 978                       NaN                        NaN
# 979                       NaN                        NaN
# 980                       NaN                        NaN
#
# Park  Wind Cave National Park  Yosemite National Park  Zion National Park
# 0                         NaN                     NaN                 NaN
# 1                         NaN                     NaN                 NaN
# 2                         NaN                     NaN                 3.0
# 3                         NaN                     NaN                 NaN
# 4                         NaN                     NaN                 NaN
# ..                        ...                     ...                 ...
# 976                       NaN                     NaN                 NaN
# 977                       NaN                     NaN                 NaN
# 978                       NaN                     NaN                 NaN
# 979                       NaN                     NaN                 NaN
# 980                       NaN                     NaN                 NaN
#
# [981 rows x 48 columns]

# %%
dsd_agg = dsd_pivot.groupby("Date").mean()

# %%
dsd_agg

# %%
dsd_agg.count().sort_values(ascending=False)

# %%
dsd_agg["Guadalupe Peak"].dropna()

# %%
for park in dsd_agg.count().sort_values(ascending=False).index:
    plt.title(park)
    plt.scatter(dsd_agg.index, dsd_agg[park])
    plt.xlabel("Year")
    plt.ylabel("Limiting Magnitude")
    plt.rcParams["figure.figsize"] = (15,15)
    plt.savefig(park" Limiting Magnitude by Year.png")
    plt.show()
